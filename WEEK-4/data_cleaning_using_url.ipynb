# %% [markdown]
# <a href="https://colab.research.google.com/github/ZexUni/2025-26-Zaid-Mohammed-Nazimuddin-4129-AI-B-DS/blob/main/WEEK-4/data_cleaning_using_url.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===============================
# DATA CLEANING USING DATASET FROM URL
# ===============================

import pandas as pd
import numpy as np

# Step 1: Load Dataset from URL
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# Step 2: Inspect basic information
print("Initial Shape:", df.shape)
print("\nMissing Values Before Cleaning:\n", df.isnull().sum())

# Step 3: Handle Missing Values
# Drop rows where Embarked is missing
df = df.dropna(subset=['Embarked'])

# Fill missing Age values with median
df['Age'] = df['Age'].fillna(df['Age'].median())

# Drop Cabin column (too many missing values)
df = df.drop(columns=['Cabin'])

# Step 4: Remove Duplicate Rows
df = df.drop_duplicates()

# Step 5: Fix Data Types
df['Age'] = df['Age'].astype(int)
df['Fare'] = df['Fare'].astype(float)

# Step 6: Rename Columns
df.rename(columns={
    'Pclass': 'Passenger_Class',
    'SibSp': 'Siblings_Spouses',
    'Parch': 'Parents_Children'
}, inplace=True)

# Step 7: Filter Data (Keep adults only)
df = df[df['Age'] >= 18]

# Step 8: Feature Engineering
df['Family_Size'] = df['Siblings_Spouses'] + df['Parents_Children']

# Step 9: Normalize Fare Column
df['Fare_Normalized'] = df['Fare'] / df['Fare'].max()

# Step 10: Apply Transformation using Lambda
df['Age_Group'] = df['Age'].apply(lambda x: 'Young' if x < 30 else 'Adult')

# Final Output
print("\nFinal Shape After Cleaning:", df.shape)
print("\nMissing Values After Cleaning:\n", df.isnull().sum())
print("\nCleaned Dataset Preview:\n")
print(df.head())
# Out:
# Initial Shape: (891, 12)
#
# Missing Values Before Cleaning:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Final Shape After Cleaning: (776, 14)
#
# Missing Values After Cleaning:
#  PassengerId         0
# Survived            0
# Passenger_Class     0
# Name                0
# Sex                 0
# Age                 0
# Siblings_Spouses    0
# Parents_Children    0
# Ticket              0
# Fare                0
# Embarked            0
# Family_Size         0
# Fare_Normalized     0
# Age_Group           0
# dtype: int64
#
# Cleaned Dataset Preview:
#
#    PassengerId  Survived  Passenger_Class  \
# 0            1         0                3
# 1            2         1                1
# 2            3         1                3
# ...
