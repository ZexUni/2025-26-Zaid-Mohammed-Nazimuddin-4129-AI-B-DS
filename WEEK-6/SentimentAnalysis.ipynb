# %% [markdown]
# <a href="https://colab.research.google.com/github/ZexUni/2025-26-Zaid-Mohammed-Nazimuddin-4129-AI-B-DS/blob/main/WEEK-6/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
data={
    "Review":[
        "I love this product",
        "This is bad",
        "Amazing experience",
        "Worst ever",
        "Very good quality"
    ],
    "sentinment":[1,0,1,0,1]
}
df=pd.DataFrame(data)
vectorizer=CountVectorizer()
X=vectorizer.fit_transform(df["Review"])
Y=df["sentinment"]
model=LogisticRegression()
model.fit(X,Y)
test=vectorizer.transform(["This product is amazing"])
print("Sentiment Prediction:", model.predict(test))
# Out:
# Sentiment Prediction: [1]
