# %% [markdown]
# <a href="https://colab.research.google.com/github/ZexUni/2025-26-Zaid-Mohammed-Nazimuddin-4129-AI-B-DS/blob/main/WEEK-8/support_vector_machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import svm
X=[[2,2],[4,4],[2,1],[0,2]]
y=[1,1,-1,-1]
model=svm.SVC(kernel='linear')
model.fit(X,y)
print(model.predict([[0,0]]))
# Out:
# [-1]
