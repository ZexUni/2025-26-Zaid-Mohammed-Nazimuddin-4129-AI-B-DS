# %% [markdown]
# <a href="https://colab.research.google.com/github/ZexUni/2025-26-Zaid-Mohammed-Nazimuddin-4129-AI-B-DS/blob/main/WEEK-9/similarity_and_distances.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.spatial import distance
from scipy.stats import pearsonr
import numpy as np
p1=np.array([2,3])
p2=np.array([5,7])
euc=distance.euclidean(p1,p2)
mh=distance.cityblock(p1,p2)
cb=distance.cosine(p1,p2)
cs=1-cb
set1,set2=set(p1),set(p2)
js=len(set1&set2)|len(set1&set2)
r=pearsonr(p1,p2)
print("Euclidean Distance:",euc)
print("Manhatten Distance:",mh)
print("Chebyshev Distance:",cb)
print("Cosine Similarity:",cs)
print("Jaccord Similarity:",js)
print("Pearsonr Coefficient:",r)
# Out:
# Euclidean Distance: 5.0
# Manhatten Distance: 7
# Chebyshev Distance: 0.0005198856603004787
# Cosine Similarity: 0.9994801143396995
# Jaccord Similarity: 0
# Pearsonr Coefficient: PearsonRResult(statistic=np.float64(1.0), pvalue=np.float64(1.0))
