# %% [markdown]
# <a href="https://colab.research.google.com/github/ZexUni/2025-26-Zaid-Mohammed-Nazimuddin-4129-AI-B-DS/blob/main/WEEK-5/Z_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data=[10,20,30,40,50]
mean=np.mean(data)
print("Mean:", mean)
std_dev=np.std(data,ddof=1)
print("Standard Deviation:", std_dev)
x=40
z_score=(x-mean)/std_dev
print("Z-Score of 40:",z_score)
# Out:
# Mean: 30.0
# Standard Deviation: 15.811388300841896
# Z-Score of 40: 0.6324555320336759
